# %% [markdown]
# # Load and Visualize Historical Prices
#
# A simple demo on working with the retrieved prices.

# %%
import glob

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="darkgrid", palette="muted", font="monospace", rc={"lines.linewidth": 2})

# %% [markdown]
# ### Load Stock and Option Prices

# %%
stock_ticker = "SPY"

stocks = pd.read_parquet(glob.glob(f"./data/prices/stocks/{stock_ticker}/*.parquet")).sort_index()
stocks
# Out:
#                           ticker      open     close       low    high  volume
# timestamp
# 2021-01-04 04:00:00-05:00    SPY  375.6400  375.6900  375.6400  375.69    2606
# 2021-01-04 04:01:00-05:00    SPY  375.6900  375.7900  375.6900  375.81   16041
# 2021-01-04 04:02:00-05:00    SPY  375.8400  375.8200  375.7900  375.88   12514
# 2021-01-04 04:04:00-05:00    SPY  375.9000  375.9100  375.9000  376.04    8995
# 2021-01-04 04:05:00-05:00    SPY  375.9000  375.8800  375.8800  375.90    4550
# ...                          ...       ...       ...       ...     ...     ...
# 2025-10-31 19:54:00-04:00    SPY  681.8000  681.8000  681.8000  681.80     196
# 2025-10-31 19:56:00-04:00    SPY  681.8100  681.8000  681.8000  681.81    1450
# 2025-10-31 19:57:00-04:00    SPY  681.8200  681.8500  681.8200  681.85     798
# 2025-10-31 19:58:00-04:00    SPY  681.8301  681.8300  681.8300  681.85    1686
# 2025-10-31 19:59:00-04:00    SPY  681.8300  681.7501  681.7501  681.83    2800
#
# [995735 rows x 6 columns]

# %%
options = pd.read_parquet(glob.glob(f"./data/prices/options/{stock_ticker}/*.parquet")).sort_index()
options
# Out:
#                                           ticker   open  close    low   high  \
# timestamp
# 2024-01-02 09:30:00-05:00   O:SPY240105C00485000   0.06   0.06   0.06   0.06
# 2024-01-02 09:30:00-05:00  O:SPYG240315C00060000   5.60   5.60   5.60   5.60
# 2024-01-02 09:30:00-05:00  O:SPYG240315C00066000   1.30   1.30   1.30   1.30
# 2024-01-02 09:30:00-05:00  O:SPYG240315C00067000   2.13   2.13   2.13   2.13
# 2024-01-02 09:30:00-05:00  O:SPYG240216C00067000   0.55   0.55   0.55   0.55
# ...                                          ...    ...    ...    ...    ...
# 2025-10-31 16:14:00-04:00   O:SPY251107P00679000   3.52   3.52   3.52   3.52
# 2025-10-31 16:14:00-04:00   O:SPY251103P00680000   1.46   1.42   1.40   1.46
# 2025-10-31 16:14:00-04:00   O:SPY251107P00680000   3.88   3.86   3.86   3.91
# 2025-10-31 16:14:00-04:00   O:SPY251104P00666000   0.33   0.32   0.32   0.33
# 2025-10-31 16:14:00-04:00   O:SPY251128P00687000  12.08  12.08  12.08  12.08
#
#                            volume
# timestamp
# 2024-01-02 09:30:00-05:00     212
# 2024-01-02 09:30:00-05:00       5
# 2024-01-02 09:30:00-05:00       1
# 2024-01-02 09:30:00-05:00       1
# 2024-01-02 09:30:00-05:00       6
# ...                           ...
# 2025-10-31 16:14:00-04:00      10
# 2025-10-31 16:14:00-04:00     112
# 2025-10-31 16:14:00-04:00      23
# 2025-10-31 16:14:00-04:00       6
# 2025-10-31 16:14:00-04:00      10
#
# [59200427 rows x 6 columns]

# %%
stocks["close"].plot(
    figsize=(12, 6),
    title=f"{stocks['ticker'].iloc[0]} price",
    xlabel="Date",
    ylabel="Price",
)
plt.show()

# %% [markdown]
# ### Load Crypto Prices

# %%
crypto_ticker = "BTC-USD"

crypto = pd.read_parquet(glob.glob(f"./data/prices/crypto/{crypto_ticker}/*.parquet")).sort_index()
crypto
# Out:
#                               ticker      open     close       low      high  \
# timestamp
# 2024-03-31 20:00:00-04:00  X:BTC-USD  71291.50  71213.11  71200.02  71373.00
# 2024-03-31 20:01:00-04:00  X:BTC-USD  71217.00  71247.73  71188.01  71355.00
# 2024-03-31 20:02:00-04:00  X:BTC-USD  71247.69  71245.00  71156.01  71312.00
# 2024-03-31 20:03:00-04:00  X:BTC-USD  71199.90  71253.92  71125.04  71320.00
# 2024-03-31 20:04:00-04:00  X:BTC-USD  71252.56  71240.05  71224.06  71326.00
# ...                              ...       ...       ...       ...       ...
# 2024-04-01 19:55:00-04:00  X:BTC-USD  69770.00  69716.02  69716.01  69770.00
# 2024-04-01 19:56:00-04:00  X:BTC-USD  69716.02  69695.00  69691.00  69769.90
# 2024-04-01 19:57:00-04:00  X:BTC-USD  69709.50  69704.61  69703.49  69750.10
# 2024-04-01 19:58:00-04:00  X:BTC-USD  69706.10  69694.53  69689.05  69712.14
# 2024-04-01 19:59:00-04:00  X:BTC-USD  69689.77  69681.10  69679.02  69705.30
#
#                               volume
# timestamp
# 2024-03-31 20:00:00-04:00  17.872117
# 2024-03-31 20:01:00-04:00  15.932094
# 2024-03-31 20:02:00-04:00  25.876711
# 2024-03-31 20:03:00-04:00  13.056548
# 2024-03-31 20:04:00-04:00   4.069928
# ...                              ...
# 2024-04-01 19:55:00-04:00   2.003530
# 2024-04-01 19:56:00-04:00   5.803169
# 2024-04-01 19:57:00-04:00   2.413407
# 2024-04-01 19:58:00-04:00   2.191675
# 2024-04-01 19:59:00-04:00   1.522611
#
# [1440 rows x 6 columns]

# %%
crypto["close"].plot(
    figsize=(12, 6),
    title=f"{crypto['ticker'].iloc[0]} price",
    xlabel="Date",
    ylabel="Price",
)
plt.show()

# %% [markdown]
# ### Load Forex Prices

# %%
forex_ticker = "EUR-USD"

forex = pd.read_parquet(glob.glob(f"./data/prices/forex/{forex_ticker}/*.parquet")).sort_index()
forex
# Out:
#                               ticker     open    close     low     high  \
# timestamp
# 2024-03-31 20:00:00-04:00  C:EUR-USD  1.07920  1.07920  1.0791  1.07933
# 2024-03-31 20:01:00-04:00  C:EUR-USD  1.07920  1.07931  1.0791  1.07942
# 2024-03-31 20:02:00-04:00  C:EUR-USD  1.07930  1.07931  1.0792  1.07932
# 2024-03-31 20:03:00-04:00  C:EUR-USD  1.07931  1.07945  1.0792  1.07951
# 2024-03-31 20:04:00-04:00  C:EUR-USD  1.07945  1.07945  1.0793  1.07950
# ...                              ...      ...      ...     ...      ...
# 2024-04-01 19:55:00-04:00  C:EUR-USD  1.07379  1.07376  1.0736  1.07380
# 2024-04-01 19:56:00-04:00  C:EUR-USD  1.07379  1.07372  1.0736  1.07380
# 2024-04-01 19:57:00-04:00  C:EUR-USD  1.07375  1.07366  1.0736  1.07379
# 2024-04-01 19:58:00-04:00  C:EUR-USD  1.07360  1.07365  1.0735  1.07370
# 2024-04-01 19:59:00-04:00  C:EUR-USD  1.07367  1.07370  1.0735  1.07373
#
#                            volume
# timestamp
# 2024-03-31 20:00:00-04:00      61
# 2024-03-31 20:01:00-04:00      78
# 2024-03-31 20:02:00-04:00      62
# 2024-03-31 20:03:00-04:00      75
# 2024-03-31 20:04:00-04:00      50
# ...                           ...
# 2024-04-01 19:55:00-04:00      63
# 2024-04-01 19:56:00-04:00      72
# 2024-04-01 19:57:00-04:00      77
# 2024-04-01 19:58:00-04:00      34
# 2024-04-01 19:59:00-04:00      47
#
# [1440 rows x 6 columns]

# %%
forex["close"].plot(
    figsize=(12, 6),
    title=f"{forex['ticker'].iloc[0]} price",
    xlabel="Date",
    ylabel="Price",
)
plt.show()
