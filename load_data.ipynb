# %% [markdown]
# # Load and visualize retrieved data

# %%
import glob

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="darkgrid", palette="muted", font="monospace", rc={"lines.linewidth": 2})

ticker = "AAPL"

# %%
stocks = pd.read_parquet(glob.glob(f"./data/stocks/{ticker}/*.parquet")).sort_index()
stocks
# Out:
#                           ticker    open   close     low    high   volume
# timestamp
# 2024-01-02 04:00:00-05:00   AAPL  191.52  190.20  190.00  191.52  18933.0
# 2024-01-02 04:01:00-05:00   AAPL  190.11  190.00  190.00  190.13   8562.0
# 2024-01-02 04:02:00-05:00   AAPL  189.90  189.82  189.82  189.90   5355.0
# 2024-01-02 04:03:00-05:00   AAPL  189.87  189.87  189.80  189.87   4405.0
# 2024-01-02 04:04:00-05:00   AAPL  189.90  189.90  189.90  189.95   2225.0
# ...                          ...     ...     ...     ...     ...      ...
# 2024-01-31 19:54:00-05:00   AAPL  185.52  185.50  185.50  185.52   1167.0
# 2024-01-31 19:55:00-05:00   AAPL  185.53  185.51  185.51  185.53    365.0
# 2024-01-31 19:56:00-05:00   AAPL  185.51  185.53  185.51  185.53    582.0
# 2024-01-31 19:57:00-05:00   AAPL  185.55  185.75  185.55  185.75   4017.0
# 2024-01-31 19:59:00-05:00   AAPL  185.70  185.70  185.70  185.70   2358.0
#
# [15996 rows x 6 columns]

# %%
options = pd.read_parquet(glob.glob(f"./data/options/{ticker}/*.parquet")).sort_index()
options
# Out:
#                                           ticker   open  close    low   high  \
# timestamp
# 2024-01-02 09:30:00-05:00  O:AAPL260116C00185000  34.50  34.50  34.50  34.50
# 2024-01-02 09:30:00-05:00  O:AAPL240419P00175000   3.65   3.65   3.65   3.65
# 2024-01-02 09:30:00-05:00  O:AAPL240419P00185000   6.70   6.35   6.35   6.75
# 2024-01-02 09:30:00-05:00  O:AAPL240419P00165000   2.00   2.00   2.00   2.00
# 2024-01-02 09:30:00-05:00  O:AAPL240419P00160000   1.50   1.55   1.50   1.55
# ...                                          ...    ...    ...    ...    ...
# 2024-01-31 15:59:00-05:00  O:AAPL240621P00185000   9.00   9.00   9.00   9.00
# 2024-01-31 15:59:00-05:00  O:AAPL240209C00182500   5.52   5.41   5.41   5.52
# 2024-01-31 15:59:00-05:00  O:AAPL240202P00180000   1.52   1.68   1.52   1.68
# 2024-01-31 15:59:00-05:00  O:AAPL240517C00220000   0.64   0.63   0.63   0.64
# 2024-01-31 15:59:00-05:00  O:AAPL240621C00220000   1.10   1.10   1.10   1.10
#
#                            volume
# timestamp
# 2024-01-02 09:30:00-05:00       1
# 2024-01-02 09:30:00-05:00       4
# 2024-01-02 09:30:00-05:00      32
# 2024-01-02 09:30:00-05:00       1
# 2024-01-02 09:30:00-05:00       8
# ...                           ...
# 2024-01-31 15:59:00-05:00      11
# 2024-01-31 15:59:00-05:00      11
# 2024-01-31 15:59:00-05:00    1232
# 2024-01-31 15:59:00-05:00      10
# 2024-01-31 15:59:00-05:00       5
#
# [571591 rows x 6 columns]

# %%
stocks["close"].plot(
    figsize=(12, 6),
    title=f"{stocks['ticker'].iloc[0]} price",
    xlabel="Date",
    ylabel="Price",
)
plt.show()
