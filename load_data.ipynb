# %% [markdown]
# # Load and visualize retrieved data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="darkgrid", palette="muted", font="monospace", rc={"lines.linewidth": 2})

# %%
ticker = "AAPL"

df = pd.read_parquet(f"./data/{ticker}").set_index("timestamp")
df
# Out:
#                        open    high     low   close   volume      vwap  \
# timestamp
# 2024-01-02 09:00:00  191.52  191.52  190.00  190.20  18933.0  190.2570
# 2024-01-02 09:01:00  190.11  190.13  190.00  190.00   8562.0  190.0787
# 2024-01-02 09:02:00  189.90  189.90  189.82  189.82   5355.0  189.8463
# 2024-01-02 09:03:00  189.87  189.87  189.80  189.87   4405.0  189.8634
# 2024-01-02 09:04:00  189.90  189.95  189.90  189.90   2225.0  189.9215
# ...                     ...     ...     ...     ...      ...       ...
# 2024-05-01 23:54:00  170.49  170.49  170.49  170.49   5032.0  170.4894
# 2024-05-01 23:55:00  170.41  170.49  170.41  170.49    660.0  170.4502
# 2024-05-01 23:56:00  170.49  170.49  170.30  170.42   2068.0  170.3992
# 2024-05-01 23:57:00  170.35  170.35  170.35  170.35    181.0  170.3477
# 2024-05-01 23:58:00  170.35  170.35  170.35  170.35    691.0  170.3430
#
#                      transactions   otc
# timestamp
# 2024-01-02 09:00:00           612  None
# 2024-01-02 09:01:00           425  None
# 2024-01-02 09:02:00           129  None
# 2024-01-02 09:03:00            83  None
# 2024-01-02 09:04:00            87  None
# ...                           ...   ...
# 2024-05-01 23:54:00            11  None
# 2024-05-01 23:55:00            33  None
# 2024-05-01 23:56:00            51  None
# 2024-05-01 23:57:00            18  None
# 2024-05-01 23:58:00            24  None
#
# [66844 rows x 8 columns]

# %%
df["close"].plot(
    figsize=(12, 6),
    title=f"{ticker} closing price",
    xlabel="Date",
    ylabel="Price",
)
plt.show()
