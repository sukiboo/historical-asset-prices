# %% [markdown]
# # Load and visualize retrieved data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="darkgrid", palette="muted", font="monospace", rc={"lines.linewidth": 2})

# %%
stocks = pd.read_parquet(f"./data/stocks/AAPL/")
stocks
# Out:
#                     timestamp ticker    open   close     low    high   volume
# 0   2024-01-02 04:00:00-05:00   AAPL  191.52  190.20  190.00  191.52  18933.0
# 1   2024-01-02 04:01:00-05:00   AAPL  190.11  190.00  190.00  190.13   8562.0
# 2   2024-01-02 04:02:00-05:00   AAPL  189.90  189.82  189.82  189.90   5355.0
# 3   2024-01-02 04:03:00-05:00   AAPL  189.87  189.87  189.80  189.87   4405.0
# 4   2024-01-02 04:04:00-05:00   AAPL  189.90  189.90  189.90  189.95   2225.0
# ..                        ...    ...     ...     ...     ...     ...      ...
# 842 2024-01-02 19:55:00-05:00   AAPL  185.24  185.27  185.24  185.27   1214.0
# 843 2024-01-02 19:56:00-05:00   AAPL  185.28  185.23  185.23  185.28   1048.0
# 844 2024-01-02 19:57:00-05:00   AAPL  185.23  185.23  185.23  185.23    907.0
# 845 2024-01-02 19:58:00-05:00   AAPL  185.25  185.25  185.25  185.25    851.0
# 846 2024-01-02 19:59:00-05:00   AAPL  185.21  185.20  185.20  185.21   3423.0
#
# [847 rows x 7 columns]

# %%
options = pd.read_parquet(f"./data/options/AAPL/")
options
# Out:
#                       timestamp                 ticker   open  close    low  \
# 0     2024-01-02 09:30:00-05:00  O:AAPL260116C00185000  34.50  34.50  34.50
# 1     2024-01-02 09:30:00-05:00  O:AAPL260116C00180000  37.40  37.61  37.40
# 2     2024-01-02 09:30:00-05:00  O:AAPL260116C00190000  32.45  32.45  32.45
# 3     2024-01-02 09:30:00-05:00  O:AAPL260116C00160000  49.72  49.72  49.72
# 4     2024-01-02 09:30:00-05:00  O:AAPL251219C00250000   8.90   8.95   8.90
# ...                         ...                    ...    ...    ...    ...
# 40417 2024-01-02 15:59:00-05:00  O:AAPL240112C00187500   1.73   1.75   1.72
# 40418 2024-01-02 15:59:00-05:00  O:AAPL240112C00195000   0.21   0.21   0.21
# 40419 2024-01-02 15:59:00-05:00  O:AAPL240112C00197500   0.12   0.11   0.11
# 40420 2024-01-02 15:59:00-05:00  O:AAPL240112C00200000   0.06   0.06   0.06
# 40421 2024-01-02 15:59:00-05:00  O:AAPL240112C00192500   0.43   0.43   0.42
#
#         high  volume
# 0      34.50       1
# 1      37.61       4
# 2      32.45       6
# 3      49.72       1
# 4       8.95       6
# ...      ...     ...
# 40417   1.75      71
# 40418   0.21       2
# 40419   0.12     502
# 40420   0.06       7
# 40421   0.43     251
#
# [40422 rows x 7 columns]

# %%
stocks["close"].plot(
    figsize=(12, 6),
    title=f"{stocks['ticker'].iloc[0]} price",
    xlabel="Date",
    ylabel="Price",
)
plt.show()
